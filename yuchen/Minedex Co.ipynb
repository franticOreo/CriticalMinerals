# %% [markdown]
# ## Import packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import scatter_matrix
from sklearn.model_selection  import train_test_split, cross_val_score
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## EDA

# %%
pd.set_option('display.max_columns', None)

# %%
re_df = pd.read_csv('MINEDEX_CSV_20210728/ResourceEstimates.csv')

# %%
re_df.head()
# Out:
#    SiteCode       ShortTitle  ResourceCode   StartDate     EndDate  \
# 0  S0000001  Pieces of Eight             1  13/07/2005  14/09/2006
# 1  S0000002     Albury Heath             2  30/06/1999  01/10/2003
# 2  S0000002     Albury Heath             3  04/06/2003  06/02/2017
# 3  S0000002     Albury Heath             4  04/06/2003  06/02/2017
# 4  S0000002     Albury Heath         28452  07/02/2017  11/03/2019
#
#                    ReportingStandard JORCCategory JORCStatus IN_TOTAL_FLAG  \
# 0                            Unknown     Resource   Inferred            No
# 1                            Unknown     Resource  Indicated            No
# 2                            Unknown     Resource   Measured           Yes
# 3                            Unknown     Resource  Indicated           Yes
# 4  JORC (Australia, version unknown)     Resource  Indicated           Yes
#
#   In Total Type  Tonnage (Mt)  Grade   GradeUnit CommodityName  \
# ...

# %%
re_df.columns
# Out:
# Index(['SiteCode', 'ShortTitle', 'ResourceCode', 'StartDate', 'EndDate',
#        'ReportingStandard', 'JORCCategory', 'JORCStatus', 'IN_TOTAL_FLAG',
#        'In Total Type', 'Tonnage (Mt)', 'Grade', 'GradeUnit', 'CommodityName',
#        'ContainedMetal', 'ContainedMetalUnit', 'CutOffGrade',
#        'CutOffGradeUnit', 'HeavyMineralPct', 'TargetCommodityGroup',
#        'Site_MineralizationStyle', 'Site_SecondaryMineralizationStyle',
#        'Resource_MineralizationStyle',
#        'Resource_SecondaryMineralizationStyle'],
#       dtype='object')

# %%
sm_df = pd.read_csv('MINEDEX_CSV_20210728/SiteMineralization.csv')
sm_df.head()
# Out:
#    SiteCode      ShortTitle                MineralizationStyle  \
# 0  S0000002    Albury Heath  Vein and hydrothermal - undivided
# 1  S0000012         Baneygo  Vein and hydrothermal - undivided
# 2  S0000014  Christmas Well  Vein and hydrothermal - undivided
# 3  S0000015   McKenzie Well  Vein and hydrothermal - undivided
# 4  S0000024        Dohertys  Vein and hydrothermal - undivided
#
#   SecondaryMineralizationStyle                                   Ore Minerals  \
# 0       Au in shears or faults                                           Gold
# 1           Unknown/Unassigned                                            NaN
# 2           Unknown/Unassigned                                            NaN
# 3           Unknown/Unassigned                                            NaN
# 4       Au in shears or faults  Chalcopyrite,Gold,Pyrite,Scheelite,Pyrrhotite
#
#   Gangue Minerals                         Alteration Expression Ore Controls  \
# ...

# %%
sm_df.columns
# Out:
# Index(['SiteCode', 'ShortTitle', 'MineralizationStyle',
#        'SecondaryMineralizationStyle', 'Ore Minerals', 'Gangue Minerals',
#        'Alteration', 'Expression', 'Ore Controls', 'Mineralization Type',
#        'Mineralization Texture', 'Length (m)', 'Width (m)', 'Strike', 'Dip',
#        'Azimuth (degrees)', 'Depth (m)', 'Vein Style', 'Structural Modifiers',
#        'Shape', 'Relation to Host', 'Metamorphic Grade', 'Mineralization Age',
#        'Age Method', 'from Age (Ma)', 'to Age (Ma)', 'Area (km)'],
#       dtype='object')

# %%
df_co = re_df[re_df["CommodityName"] == "Cobalt"]

# %%
deposits=['Orthomagmatic mafic and ultramafic - layered mafic intrusions', 'Orthomagmatic mafic and ultramafic - komatiitic or dunitic','Orthomagmatic mafic and ultramafic - undivided']
df_co = df_co[df_co['Site_MineralizationStyle'].isin(deposits)]

# %%
df_co.head()
# Out:
#       SiteCode       ShortTitle  ResourceCode   StartDate     EndDate  \
# 5856  S0001273   Honeymoon Well          2100  31/12/1999  30/12/2009
# 6394  S0001316  Widgie Townsite          2352  22/06/2005  23/06/2005
# 6396  S0001316  Widgie Townsite          2353  22/06/2005  23/06/2005
# 6398  S0001316  Widgie Townsite          2354  22/06/2005  23/06/2005
# 6410  S0001316  Widgie Townsite         44845  29/06/2021         NaN
#
#                       ReportingStandard JORCCategory JORCStatus IN_TOTAL_FLAG  \
# 5856  JORC (Australia, version unknown)     Resource   Inferred           Yes
# 6394                            Unknown     Resource   Inferred            No
# 6396                            Unknown     Resource   Inferred            No
# 6398                            Unknown     Resource   Inferred            No
# 6410              2012 JORC (Australia)     Resource  Indicated           Yes
#
#                         In Total Type  Tonnage (Mt)   Grade GradeUnit  \
# ...

# %%
df_co.shape
# Out:
# (322, 24)

# %% [markdown]
# ## Modeling

# %%
from sklearn.model_selection import train_test_split
