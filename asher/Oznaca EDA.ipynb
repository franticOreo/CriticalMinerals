#  57  V        1139 non-null   int64
#  58  W        1139 non-null   float64
#  59  Y        1139 non-null   float64
#  60  Zn       1139 non-null   int64
#  61  B        1139 non-null   int64
#  62  Hf       1139 non-null   float64
#  63  Si       1139 non-null   int64
#  64  Zr       1139 non-null   int64
#  65  Be       1139 non-null   float64
#  66  Ga       1139 non-null   float64
#  67  Ge       1139 non-null   int64
#  68  Wt Tot   564 non-null    object
# dtypes: float64(35), int64(27), object(7)
# memory usage: 614.1+ KB

# %%
df.describe()
# Out:
#               Sample             Bi           Te            Ag             Al  \
# count    1139.000000    1139.000000  1139.000000   1139.000000    1139.000000
# mean   700589.162423     206.398297    12.988499    128.701888   29879.455663
# std       341.503667    4218.649939   139.296993    999.232819   29764.993995
# min    700001.000000      -0.020000    -0.100000     -0.050000    -100.000000
# 25%    700285.500000       0.260000     0.060000      0.500000    3100.000000
# 50%    700597.000000       1.140000     0.320000      3.000000   19800.000000
# 75%    700885.500000       7.250000     2.180000     24.000000   53350.000000
# max    701173.000000  138000.000000  4010.000000  20400.000000  161000.000000
#
#                   As             Ca           Cd            Co             Cr  \
# count    1139.000000    1139.000000  1139.000000   1139.000000    1139.000000
# mean     4125.812994   30954.433714   175.231299    177.946444    1825.680421
# std     20726.547498   49511.243021   651.408613    864.289767   20768.673947
# min        -1.000000    -100.000000    -0.050000     -1.000000     -50.000000
# 25%        14.000000    1000.000000     0.150000      5.000000     -50.000000
# 50%        82.000000    9700.000000     0.600000     20.000000     -50.000000
# 75%       695.000000   39850.000000    12.700000     72.500000      50.000000
# max    450000.000000  335000.000000  9790.000000  23500.000000  389000.000000
#
#        ...              W            Y             Zn             B  \
# count  ...    1139.000000  1139.000000    1139.000000   1139.000000
# mean   ...     321.862599    14.058385   39945.004390     83.055312
# std    ...    4687.876609    35.575042   99927.431656    629.590047
# min    ...      -0.500000    -0.100000      -5.000000    -20.000000
# 25%    ...       1.000000     2.100000      40.000000    -20.000000
# 50%    ...       5.000000     6.700000     105.000000     20.000000
# 75%    ...      20.000000    14.600000    2420.000000     40.000000
# max    ...  138000.000000   633.000000  670000.000000  10800.000000
#
#                 Hf             Si           Zr           Be           Ga  \
# count  1139.000000    1139.000000  1139.000000  1139.000000  1139.000000
# mean      2.009482  189518.964004    79.859526     6.991089    13.227919
# std       4.182302  125708.681033   136.450669   105.058764    23.498047
# min      -0.200000     200.000000   -10.000000    -1.000000    -1.000000
# 25%       0.200000   73400.000000    10.000000    -0.100000     3.000000
# 50%       1.000000  198000.000000    40.000000     0.400000     9.600000
# 75%       2.700000  289000.000000   110.000000     1.300000    16.600000
# max      94.000000  459000.000000  2230.000000  3300.000000   580.000000
#
#                 Ge
# count  1139.000000
# mean      5.951712
# std      18.995151
# min      -1.000000
# 25%       1.000000
# 50%       2.000000
# 75%       4.000000
# max     338.000000
#
# [8 rows x 62 columns]

# %%
# %matplotlib inline
df.hist(bins=50, figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EABC0D60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EAF4D040>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EB5F3340>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EB5EF790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EB5506D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EB543D90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EB543E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EB5B36A0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EB6E3550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EB68ECA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EB6AF460>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EB64FBE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EB6793A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EB71AB20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EB7452E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EB765A60>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EB78F220>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EB7B39A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EB7DC160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EB7FD8E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EB824100>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EB85A820>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EB883FA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EB8B8760>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EB8E5EE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EB91C6A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EB944E20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EB97A5E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8E8454D60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8E75CDF10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EAB582B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EAB93D30>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EB5F2370>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EA5AE130>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EA5D7580>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EA6039D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EA630E20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EA66A2E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EA696730>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EA6C3B80>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EA6EFFD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EA72E460>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EA7568B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EA784D00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EA7BD190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EA7EB5E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EA815A30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EA844E80>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EA87C310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EA8AA760>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EA8D3BB0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EA9040A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EA93D490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EA96A8E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EA995D30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EA9CE1C0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EA9FC610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EAA29A60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EAA57A00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EAA901C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EAAB9940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EAAE3160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EB9D87C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EBA02130>]],
#       dtype=object)

# %% [markdown]
# It appears a lot of variables are close to 0, possibly worth log transforming?

# %%
df.isna().sum()
# Out:
# Sample       0
# Code       937
# Au (FA)      0
# Pt           0
# Pd           0
#           ...
# Zr           0
# Be           0
# Ga           0
# Ge           0
# Wt Tot     575
# Length: 69, dtype: int64

# %%
cor = df.corr()
cor
# Out:
#           Sample        Bi        Te        Ag        Al        As        Ca  \
# Sample  1.000000 -0.039875 -0.024252  0.024092 -0.031275  0.041256  0.053039
# Bi     -0.039875  1.000000 -0.002776 -0.005408 -0.023730 -0.006724 -0.025284
# Te     -0.024252 -0.002776  1.000000  0.021029 -0.034544 -0.006712 -0.012847
# Ag      0.024092 -0.005408  0.021029  1.000000 -0.070997 -0.006210  0.051428
# Al     -0.031275 -0.023730 -0.034544 -0.070997  1.000000 -0.048001 -0.080937
# ...          ...       ...       ...       ...       ...       ...       ...
# Si     -0.129795 -0.045992  0.026646 -0.053717  0.449418 -0.043117 -0.207563
# Zr     -0.030270 -0.014719 -0.026915 -0.054595  0.476037 -0.021057 -0.060520
# Be      0.051213 -0.001265 -0.005920 -0.007537  0.081780 -0.010028  0.009177
# Ga      0.054765  0.002056 -0.017561  0.036023  0.227321 -0.037424 -0.039675
# Ge      0.036317  0.005424 -0.014630 -0.005564 -0.143311 -0.028890  0.029777
#
#               Cd        Co        Cr  ...         W         Y        Zn  \
# Sample  0.014782  0.037748  0.047685  ... -0.026548  0.046370  0.009865
# Bi     -0.012043 -0.005546 -0.004398  ...  0.008806 -0.003892 -0.017409
# Te      0.016210 -0.000478 -0.007586  ... -0.002914 -0.020654 -0.015739
# Ag      0.051889 -0.019414 -0.011586  ... -0.006665  0.091787  0.073350
# Al     -0.204026 -0.083963  0.110595  ... -0.002210  0.078343 -0.293749
# ...          ...       ...       ...  ...       ...       ...       ...
# Si     -0.277950 -0.093324 -0.087725  ...  0.016470 -0.012366 -0.394463
# Zr     -0.123906 -0.009539 -0.047949  ... -0.006690  0.296036 -0.173029
# Be     -0.016760 -0.012443 -0.006042  ...  0.008611 -0.004948 -0.023833
# Ga      0.024329 -0.050155  0.084177  ... -0.006476  0.380073  0.063167
# Ge      0.224266 -0.037319 -0.022524  ...  0.012738 -0.014859  0.494664
#
#                B        Hf        Si        Zr        Be        Ga        Ge
# Sample  0.057091  0.005780 -0.129795 -0.030270  0.051213  0.054765  0.036317
# Bi     -0.003870 -0.013952 -0.045992 -0.014719 -0.001265  0.002056  0.005424
# Te     -0.010618 -0.025083  0.026646 -0.026915 -0.005920 -0.017561 -0.014630
# Ag     -0.014724 -0.042259 -0.053717 -0.054595 -0.007537  0.036023 -0.005564
# Al      0.086602  0.418630  0.449418  0.476037  0.081780  0.227321 -0.143311
# ...          ...       ...       ...       ...       ...       ...       ...
# Si      0.042993  0.215208  1.000000  0.242605  0.018309  0.003008 -0.195223
# Zr      0.026330  0.808300  0.242605  1.000000 -0.002856  0.099313 -0.081963
# Be      0.124782  0.063537  0.018309 -0.002856  1.000000  0.128613  0.010623
# Ga      0.050236  0.151643  0.003008  0.099313  0.128613  1.000000  0.152700
# Ge     -0.002933 -0.057773 -0.195223 -0.081963  0.010623  0.152700  1.000000
#
# [62 rows x 62 columns]

# %%
sns.heatmap(cor, cmap="coolwarm")

# %% [markdown]
# Elements La, Nd, Gd, Ho, Yb have some strong intercorrelations, Zn and Ga also see some correlations with that group

# %%
df1 = df.loc[:,['La', 'Nd', 'Gd', 'Ho','Yb','Zn', 'Ga']]
df1.head()
# Out:
#     La    Nd    Gd    Ho    Yb      Zn    Ga
# 0  2.1  1.20  0.30 -0.05  0.10  153000  11.0
# 1  6.0  7.15  3.15  0.75  2.05    3780   2.0
# 2  0.8  0.60  0.10 -0.05 -0.05  219000  -1.0
# 3  8.5  7.80  1.65  0.20  0.45     755  -1.0
# 4  1.1  0.90  0.40  0.15  0.75  173000  -1.0

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df1, figsize=(16,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F5BF3670>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F72C6520>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F5F92610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F605B370>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F74BDBB0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F74F4D90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F74F4190>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F5DF2100>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F7493EB0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F6A883A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F7387F70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F737F850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F7497C10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F724FB20>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F2F889D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F606E310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F5F87D30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F3F26A60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F8A023A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F6E5EA00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F6E42D90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002A8EF211F40>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F7416460>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F6D66130>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F8A35190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F8A06400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F8785190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F8731040>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F8A4CB80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F74364F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F8794640>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F6FD5C70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F87760A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F8789E20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F87217C0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F745CCD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F8769190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F744FC70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F873B340>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F88D0D90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F88B4460>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F8916BB0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F88E4550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F88BB820>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F89B2880>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F8A8EBE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F8980CA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F8A7E160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F94D5460>]],
#       dtype=object)

# %%
df2 = np.log(df1)
scatter_matrix(df2, figsize=(16,12))
# Out:
# <ipython-input-110-dc70ebb773b8>:1: RuntimeWarning: invalid value encountered in log
#   df2 = np.log(df1)
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F7136160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F9596970>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F58C3550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F5727CD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F5744430>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F5E26AF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F5E26BE0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F54AB9A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F92572B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F9244A30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F565B1F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F587B4F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F6D16130>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F6D178B0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F5F260D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F591D7F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F698AF70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F6996730>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F5857EB0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F55D7670>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F6470DF0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F62EC5B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F62FDD30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F59BA4F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F9349C70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F6637430>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F662FBB0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F5BB8490>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F592FB20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F6327280>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F634EA00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F63851C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F63AD940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F63D6160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F640E880>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F64380A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F64EE7C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F6517F40>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F658B700>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F65B6E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F65EA640>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F6614DC0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F668B580>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F959E7F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F6D6F460>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F5C75670>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F9376F40>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F5DFBCD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A8F5ADD8E0>]],
#       dtype=object)

# %%
cor2=df2.corr()
sns.heatmap(cor2)

# %% [markdown]
# # Hierarchical clustering

# %%
import scipy
from scipy.cluster import hierarchy as sch
import sklearn
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
# Out:
# Sample     0
# Code       0
# Au (FA)    0
# Pt         0
# Pd         0
#           ..
# Zr         0
# Be         0
# Ga         0
# Ge         0
# Wt Tot     0
# Length: 69, dtype: int64

# %%
df.columns
# Out:
# Index(['Sample', 'Code', 'Au (FA)', 'Pt', 'Pd', 'Au (AR)', 'Bi', 'Te', 'Hg',
#        'Ag', 'Al', 'As', 'Ca', 'Cd', 'Co', 'Cr', 'Cs', 'Cu', 'Fe', 'In', 'K',
#        'La', 'Ce', 'Pr', 'Nd', 'Sm', 'Eu', 'Gd', 'Tb', 'Dy', 'Ho', 'Er', 'Tm',
#        'Yb', 'Lu', 'Li', 'Mg', 'Mn', 'Mo', 'Na', 'Nb', 'Ni', 'P', 'Pb', 'Rb',
#        'Re', 'S', 'Sb', 'Sc', 'Se', 'Sn', 'Sr', 'Ta', 'Th', 'Ti', 'Tl', 'U',
#        'V', 'W', 'Y', 'Zn', 'B', 'Hf', 'Si', 'Zr', 'Be', 'Ga', 'Ge', 'Wt Tot'],
#       dtype='object')

# %%
df_scaled = df.drop(['Code','Wt Tot'], axis=1)
df_scaled = df_scaled[df_scaled != 'IS']

df_scaled = scaler.fit_transform(df_scaled)
df_scaled = pd.DataFrame(df_scaled)
df_scaled.columns = df.columns[2:]
df_scaled.head()
# Out:
# C:\Users\caley\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
#     Au (FA)        Pt        Pd   Au (AR)        Bi        Te        Hg  \
# 0  0.000000  0.000041  0.000197  0.000199  0.000032  0.000077  0.000030
# 1  0.000853  0.000009  0.000132  0.000199  0.000008  0.000906  0.000080
# 2  0.001706  0.000131  0.000197  0.000199  0.000121  0.000870  0.000030
# 3  0.002560  0.000009  0.000263  0.000397  0.000008  0.000005  0.000224
# 4  0.003413  0.000269  0.000263  0.000397  0.000343  0.000003  0.000040
#
#          Ag        Al        As  ...         Y        Zn         B   Hf  \
# 0  0.000026  0.004488  0.017381  ...  0.000014  0.002053  0.228364  0.0
# 1  0.000008  0.002159  0.163873  ...  0.000022  0.029379  0.005649  0.0
# 2  0.004059  0.010542  0.001241  ...  0.000036  0.000632  0.326871  0.0
# 3  0.000003  0.000125  0.235258  ...  0.000014  0.010109  0.001134  0.0
# 4  0.000259  0.007944  0.122284  ...  0.000040  0.007266  0.258214  0.0
#
#          Si        Zr        Be   Ga        Ge   Wt Tot
# 0  0.006369  0.074106  0.031250  0.0  0.020654  0.00590
# 1  0.004246  0.248038  0.013393  0.0  0.005164  0.00000
# 2  0.000000  0.155405  0.000000  0.0  0.000000  0.00885
# 3  0.023355  0.531386  0.035714  0.0  0.000000  0.00000
# 4  0.000000  0.309067  0.000000  0.0  0.000000  0.00885
#
# [5 rows x 67 columns]

# %%
df_scaled=df_scaled.dropna()

# %%
plt.rcParams['figure.figsize'] = [20,15]

# %%
dendro2 = sch.dendrogram(sch.linkage(df_scaled, method = 'complete'))
plt.title('Dendrogram')
plt.xlabel('Minerals')
plt.ylabel('Euclidean Distances')
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering

cluster = AgglomerativeClustering(n_clusters=4, affinity='euclidean', linkage='ward')

cluster.fit(df_scaled)
labels = cluster.labels_
labels
# Out:
# array([2, 3, 2, ..., 0, 1, 1], dtype=int64)

# %%
len(labels)
# Out:
# 1135
